# %%
import config as cfg
from img2box import *

# %%
bounding_boxes(
    model=cfg.MODEL,
    conf_thresh=0.1,
    nms_thresh=0.5,
    image_dir=r'images\dog.jpg',
    names=cfg.CLASS_NAMES,
    device=cfg.DEVICE,
    save_as='predictions/dogs.jpg'
    )
# Out:
# dog       : 0.437662
# bicycle   : 0.335407
# truck     : 0.148624
# motorcycle: 0.011312
# Saving to.... predictions/dogs.jpg
# <PIL.Image.Image image mode=RGB size=768x576>
